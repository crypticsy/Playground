# %%
! pip install beautifulsoup4
! pip install html5lib
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/crypticsy/anaconda3/envs/bhoos/lib/python3.12/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/crypticsy/anaconda3/envs/bhoos/lib/python3.12/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: html5lib in /Users/crypticsy/anaconda3/envs/bhoos/lib/python3.12/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/crypticsy/anaconda3/envs/bhoos/lib/python3.12/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /Users/crypticsy/anaconda3/envs/bhoos/lib/python3.12/site-packages (from html5lib) (0.5.1)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# URL of the web page you want to extract tables from
url = 'https://intranet.londonmet.ac.uk/course-catalogue/courses/search-results'

# Send an HTTP GET request to the URL
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the first table element in the parsed HTML
    table = soup.find('table')
    
    # Prepare to collect rows of data
    data = []
    
    if table:
        # Find all rows in the table
        rows = table.find_all('tr')
        
        # Get headers from the first row
        headers = [header.text.strip() for header in rows[0].find_all('th')]
        
        # Iterate over all rows (excluding the header row)
        for row in rows[1:]:
            cells = row.find_all('td')
            row_data = {}
            for index, cell in enumerate(cells):
                # Check if the cell contains an 'a' tag (hyperlink)
                a_tag = cell.find('a')
                if a_tag:
                    # Get the text and URL from the 'a' tag
                    row_data[headers[index]] = {'text': a_tag.text.strip(), 'url': a_tag['href']}
                else:
                    # Get text if no 'a' tag is present
                    row_data[headers[index]] = {'text': cell.text.strip()}
            data.append(row_data)
        
        # Convert the list of dictionaries into a DataFrame
        df = pd.DataFrame(data)
        display(df)
    else:
        print("No tables found in the HTML.")
else:
    print(f"Failed to retrieve data from URL. Status code: {response.status_code}")
# Out:
#                                                   Code  \
# 0    {'text': 'APARAPRB', 'url': '/course-catalogue...
# 1                                 {'text': 'APMAAEPP'}
# 2                                 {'text': 'APPAFEWL'}
# 3                                 {'text': 'APPAFSWL'}
# 4                                 {'text': 'APPAHTSA'}
# ..                                                 ...
# 382                               {'text': 'UOIFPSCI'}
# 383                               {'text': 'UOIFPSSH'}
# 384                               {'text': 'USCIMCPM'}
# 385                               {'text': 'USICMCM3'}
# 386                               {'text': 'USICMCM5'}
#
#                                             Full title  \
# 0    {'text': 'Architect Apprenticeship (Level 7) (...
# 1    {'text': 'Architecture Apprenticeship (RIBA 2 ...
# 2    {'text': 'PGCE Primary Apprenticeship 5-11 (We...
# 3    {'text': 'PGCE Primary Apprenticeship 5-11 SEN...
# 4    {'text': 'PGCE Primary Apprenticeship (Hackney...
# ..                                                 ...
# 382  {'text': 'International Foundation Programme S...
# 383  {'text': 'International Foundation Programme S...
# 384  {'text': 'CIM Certificate in Professional Mark...
# 385  {'text': 'CICM Diploma in Credit Management Le...
# 386  {'text': 'CICM Diploma in Credit Management Le...
#
#                           Type          Info
# 0     {'text': 'Postgraduate'}  {'text': ''}
# 1     {'text': 'Postgraduate'}  {'text': ''}
# 2     {'text': 'Postgraduate'}  {'text': ''}
# 3     {'text': 'Postgraduate'}  {'text': ''}
# 4     {'text': 'Postgraduate'}  {'text': ''}
# ..                         ...           ...
# 382  {'text': 'Undergraduate'}  {'text': ''}
# 383  {'text': 'Undergraduate'}  {'text': ''}
# 384  {'text': 'Undergraduate'}  {'text': ''}
# 385  {'text': 'Undergraduate'}  {'text': ''}
# 386  {'text': 'Undergraduate'}  {'text': ''}
#
# [387 rows x 4 columns]

# %%
# Expand all the json cells in the DataFrame
df_expanded = df.applymap(lambda x: x['text'] if isinstance(x, dict) else x)
df_expanded['URL'] = df['Full title'].apply(lambda x: np.nan if not isinstance(x, dict) or 'url' not in x else x['url'])
df_expanded.columns = ['course_code', 'full_title', 'type', 'info', 'url']
display(df_expanded)
# Out:
# /var/folders/n5/mm68ph654jj0kwghx08j70l40000gp/T/ipykernel_94725/2164497355.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_expanded = df.applymap(lambda x: x['text'] if isinstance(x, dict) else x)
#     course_code                                         full_title  \
# 0      APARAPRB  Architect Apprenticeship (Level 7) (RIBA Part ...
# 1      APMAAEPP  Architecture Apprenticeship (RIBA 2 and 3) - M...
# 2      APPAFEWL  PGCE Primary Apprenticeship 5-11 (West London ...
# 3      APPAFSWL  PGCE Primary Apprenticeship 5-11 SEND (West Lo...
# 4      APPAHTSA  PGCE Primary Apprenticeship (Hackney Teaching ...
# ..          ...                                                ...
# 382    UOIFPSCI        International Foundation Programme Sciences
# 383    UOIFPSSH  International Foundation Programme Social Scie...
# 384    USCIMCPM          CIM Certificate in Professional Marketing
# 385    USICMCM3          CICM Diploma in Credit Management Level 3
# 386    USICMCM5          CICM Diploma in Credit Management Level 5
#
#               type info                                                url
# 0     Postgraduate       /course-catalogue/course-specifications/2023-2...
# 1     Postgraduate                                                     NaN
# 2     Postgraduate                                                     NaN
# 3     Postgraduate                                                     NaN
# 4     Postgraduate                                                     NaN
# ..             ...  ...                                                ...
# 382  Undergraduate                                                     NaN
# 383  Undergraduate                                                     NaN
# 384  Undergraduate                                                     NaN
# 385  Undergraduate                                                     NaN
# 386  Undergraduate                                                     NaN
#
# [387 rows x 5 columns]

# %%
df_expanded.to_csv('courses.csv', index=False)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
results_header = soup.find('div', {'id':'results_header'}).text.replace('\n\n', '\n').replace('\n\n', '\n').strip()

with open('scrapper_info.txt', 'w') as file:
  file.write(results_header)

# %% [markdown]
# -----

# %%
base_url = 'https://intranet.londonmet.ac.uk'
data = []

def find_entry_requirements(sp):
    for div in sp.find_all('div', {'class':"panel-default"}):
        if div.find('h3').text == 'Entry requirements':
            return div.find('div', {'class':'panel-body'})


for url in df_expanded[df_expanded.url.notnull()]['url']:
    response = requests.get(base_url + url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser').find('div', {'id':'course_specification_and_structures'})
        data.append({
            'url': url,
            'title' : BeautifulSoup(response.text, 'html.parser').find('h1').text.strip(),
            'course_requirements': soup.find('table', {'class':'specifications'}),
            'entry_requirements' : find_entry_requirements(soup)
        })
        
    else:
        data.append('Failed to retrieve course info.')

# %%
course_specifications = pd.DataFrame(data)
course_specifications.to_csv('course_specifications.csv', index=False)

# %% [markdown]
# ---------

# %%
response = requests.get('https://www.londonmet.ac.uk/international/applying/entry-requirements-by-country/')

# %%
entry_requirements_country = []

data = BeautifulSoup(response.text)

for country in data.find_all('div', {'class':'col-md-6'}):
    if country.find('h2'):
        country_url = "https://www.londonmet.ac.uk" + country.find('a')['href']
        
        new_soup = BeautifulSoup(requests.get(country_url).text).find_all('table')
        
        entry_requirements_country.append({
            'country': country.find('h2').text,
            'url': country_url,
            'academic' : new_soup[0],
            'mathematics and english' : new_soup[1],
        })

df = pd.DataFrame(entry_requirements_country)
df.to_csv('entry_requirements_country.csv', index=False)

# %% [markdown]
# ------

# %%
! pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.3/251.3 kB 7.4 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %%
data = pd.read_excel("2024-tariff-tables-march-24.xlsx", sheet_name="TARIFF POINTS BENCHMARK", header=9)
data
# Out:
#                                    Qualification Title Awarding Body    GLH  \
# 0     A Level (Double Award) and Advanced VCE (Doub...       Various    720
# 1     A Level (Double Award) and Advanced VCE (Doub...       Various    720
# 2     A Level (Double Award) and Advanced VCE (Doub...       Various    720
# 3     A Level (Double Award) and Advanced VCE (Doub...       Various    720
# 4     A Level (Double Award) and Advanced VCE (Doub...       Various    720
# ..                                                 ...           ...    ...
# 227                                            T level       Various  1000+
# 228                                            T level       Various  1000+
# 229   Welsh Baccalaureate Advanced Diploma – Core (...          WJEC    180
# 230                           WEW/PSE/WRE/II component          WJEC    350
# 231  Welsh Baccalaureate Advanced Diploma - Total P...          WJEC    530
#
#     Size band       Grade Grade Band  TARIFF POINTS Qualification offered in  \
# 0       (4+4)        A*A*    (14,14)            112      Multiple UK nations
# 1       (4+4)         A*A    (14,12)            104      Multiple UK nations
# 2       (4+4)          AA    (12,12)             96      Multiple UK nations
# 3       (4+4)          AB    (12,10)             88      Multiple UK nations
# 4       (4+4)          BB    (10,10)             80      Multiple UK nations
# ..        ...         ...        ...            ...                      ...
# 227   (4+4+4)    P (A*-C)          8             96             England only
# 228   (4+4+4)  P (D or E)          6             72             England only
# 229         2           P          6             12               Wales only
# 230         4           P          9             36               Wales only
# 231         6           P          8             48               Wales only
#
#                  Qualification Type Awarding Body full title
# 0    Qualification Type unavailable                  Various
# 1    Qualification Type unavailable                  Various
# 2    Qualification Type unavailable                  Various
# 3    Qualification Type unavailable                  Various
# 4    Qualification Type unavailable                  Various
# ..                              ...                      ...
# 227  Qualification Type unavailable                  Various
# 228  Qualification Type unavailable                  Various
# 229  Qualification Type unavailable              WJEC - CBAC
# 230  Qualification Type unavailable              WJEC - CBAC
# 231  Qualification Type unavailable              WJEC - CBAC
#
# [232 rows x 10 columns]

# %%
data.to_csv('tariff_points.csv', index=False)
